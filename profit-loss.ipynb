# %%
import pandas as pd

# %%
data_source = "static/resources/pl-2016-2020.CSV"
pl_data = pd.read_csv(data_source, encoding="ISO-8859-1")
pl_data.head()
# Out:
#                      Unnamed: 0     Jan 16     Feb 16     Mar 16     Apr 16  \
# 0       Ordinary Income/Expense        NaN        NaN        NaN        NaN
# 1                        Income        NaN        NaN        NaN        NaN
# 2         4000 · MOVING REVENUE        NaN        NaN        NaN        NaN
# 3  4010 · Moves (Use of Trucks)  122718.90  101899.40  156592.73  180209.13
# 4      4020 · Packing/Unpacking    5092.02    3671.55    4667.50    4190.00
#
#       May 16     Jun 16     Jul 16     Aug 16     Sep 16  ...     Sep 19  \
# 0        NaN        NaN        NaN        NaN        NaN  ...        NaN
# 1        NaN        NaN        NaN        NaN        NaN  ...        NaN
# 2        NaN        NaN        NaN        NaN        NaN  ...        NaN
# 3  282069.65  381478.86  335634.26  327629.86  245463.96  ...  215335.05
# 4    5569.87   17640.61   13426.52   11345.58    5679.81  ...   26753.73
#
# ...

# %%
pl_data.set_index("Unnamed: 0")
# Out:
#                                    Jan 16     Feb 16     Mar 16     Apr 16  \
# Unnamed: 0
# Ordinary Income/Expense               NaN        NaN        NaN        NaN
# Income                                NaN        NaN        NaN        NaN
# 4000 · MOVING REVENUE                 NaN        NaN        NaN        NaN
# 4010 · Moves (Use of Trucks)    122718.90  101899.40  156592.73  180209.13
# 4020 · Packing/Unpacking          5092.02    3671.55    4667.50    4190.00
# ...                                   ...        ...        ...        ...
# Other Expense                         NaN        NaN        NaN        NaN
# 9990 · Corp Income Taxes - Fed       0.00       0.00       0.00       0.00
# Total Other Expense                  0.00       0.00       0.00       0.00
# Net Other Income                   703.20     485.64  -17586.24     158.90
# Net Income                      -30852.83  -25750.73  -17721.56   -9957.69
#
# ...

# %%
dates = pl_data.columns.to_list()

# %%
for index, row in pl_data.iterrows():
    amounts = row.to_list()
    print(amounts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-53a48e7a4bbf> in <module>
#       1 for index, row in pl_data.iterrows():
# ----> 2     amounts = row[1].to_list()
#       3     print(amounts)
#
# AttributeError: 'float' object has no attribute 'to_list'

# %%
pl_data.to_json("pl_data.json", orient='records')
