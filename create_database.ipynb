# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy.orm import Session
import numpy as np

from sqlalchemy import Column, Integer, String, Float
from flask import jsonify

# %%
class pettyCash(Base):
    __tablename__ = "pettyCash"
    id = Column(Integer, primary_key=True)
    date = Column(String)
    receipt_number = Column(Integer)
    description = Column(String)
    amount_deposited = Column(Integer)
    amount_withdrawn = Column(Integer)
    amount_receivedby = Column(String)
    amount_approvedby = Column(String)
    comments = Column(String)

# %%
engine = create_engine('sqlite:///petty_cash.sqlite')
Base.metadata.create_all(engine)

# %%
session = Session(bind=engine)

# %%
engine.execute('select * from pettyCash').fetchall()
# Out:
# [(1, '05/12/2020', None, None, None, None, None, None, None),
#  (2, '05/30/2020', None, None, None, None, None, None, None),
#  (3, '', None, None, None, None, None, None, None),
#  (4, 'sdsd', 'sdf', 'sdf', 'sdf', 'sdf', 'sdf', 'ds', ''),
#  (5, 'sdg', 'sdg', 'sd', 'sdg', 'sg', 'sdg', 'sdg', ''),
#  (6, 'gsg', 3, 'xc', 44, 34, 'fgfdg', 'sgsg', ''),
#  (7, 'gsg', 3, 'xc', 44, 34, 'fgfdg', 'sgsg', ''),
#  (8, 'sdf', 'sf', 'gsdg', 'sgs', 'sdgs', 'sdgsd', 'sdg', ''),
#  (9, 'df', 'df', 'dfg', 'dfg', 'dfg', 'fdg', 'dfg', ''),
#  (10, 'fgfg', 'sg', 'sg', 'bg', 'sg', 'sgd', 'sg', ''),
#  (11, 'cg', 'gs', 'sdgs', 'sdg', 'sg', 'sdg', 'sdg', ''),
#  (12, 'fhh', 'fh', 'fgh', 'fgu', 'fu', 'fu', 'tu', ''),
#  (13, 'fghgf', 'hfh', 'hgh', 'fgh', 'fgh', 'fgh', 'h', ''),
#  (14, 'ghg', 'fhh', 'dgdg', 'dgdf', 'gdgdfg', 'dgdf', 'dg', ''),
#  (15, 'hf', 'hdh', 'dfh', 'dfh', 'dfh', 'h', 'dfh', ''),
#  (16, 'vsfs', 'dsfds', 'sdfsd', 'sdvsd', 'vzv', 'zv', 'zxv', ''),
#  (17, 'ggg', 'dg', 'fdgs', 'sdfg', 'dfg', 'dfg', 'g', ''),
#  (18, 'sdf', 'sdf', 'asdg', 'sg', 'sag', 'sag', 'sag', ''),
#  (19, 'sgs', 'sd', 'sdg', 'sg', 'sdg', 'sdg', 'sg', ''),
#  (20, 'sdfds', 'sgd', 'sdg', 'sdg', 'sdg', 'sdg', 'sdg', ''),
#  (21, 'dfg', 'dfh', 'dfh', 'he', 'gre', 'dg', 'dg', ''),
#  (22, 'sgs', 'ag', 'adg', 'asdg', 'asg', 'gag', 'agd', ''),
#  (23, 'dhd', 'sh', 'dh', 'dfh', 'dfh', 'dfh', 'dfh', ''),
#  (24, 'dfg', 'fdsh', 'dfsh', 'dfh', 'dh', 'dfh', 'dfh', ''),
#  (25, 'sgsg', 'sf', 'sdg', 'sgd', 'sdg', 'sgd', 'sdg', ''),
#  (26, 'dg', 'dfh', 'dh', 'dh', 'dfh', 'dh', 'dfh', ''),
#  (27, 'fgg', 'g', 'adg', 'dsag', 'adg', 'agd', 'agsd', ''),
#  (28, 'fgfd', 'dg', 'sg', 'sg', 'sg', 'sdg', 'sg', ''),
#  (29, 'cvb', 'bdb', 'dg', 'dfg', 'dfg', 'dfg', 'dfg', ''),
#  (30, 'sdfsd', 'sf', 'sf', 'sdf', 'sdf', 'sdf', 'sdf', ''),
#  (31, 'sgsd', 'sdg', 'ag', 'dfg', 'dfag', 'adfg', 'dafg', ''),
#  (32, 'sgsd', 'sdg', 'ag', 'dfg', 'dfag', 'adfg', 'dafg', ''),
#  (33, 'sgsd', 'sdg', 'ag', '', 'dfag', 'adfg', 'dafg', ''),
#  (34, 'sgsd', 'sdg', 'ag', '', 'dfag', 'adfg', 'dafg', ''),
#  (35, 'fsdg', 'sdf', 'fsdh', 'dfg', 'afd', 'hag', 'fgaf', ''),
#  (36, 'fxb', 'sg', 'sg', 'sg', 'sg', 's', 'sdg', ''),
#  (37, 'dfg', 'g', 'g', 'dfg', 'dfg', 'dfg', 'dfg', ''),
#  (38, 'dfg', 'g', 'g', 'dfg', 'dfg', 'dfg', 'dfg', ''),
#  (39, 'fdg', 'sg', 'sg', 'sg', 'sdg', 'sdg', 'sdg', ''),
#  (40, 'ds', 'dsf', 'dsf', 'df', 'xcb', 'cxb', 'xcb', ''),
#  (41, 'gdg', 'sfdg', 'sdfh', 'dh', 'sfd', 'sh', 'hsdf', ''),
#  (42, 'dsgda', 'dag', 'ag', 'gagd', 'sag', 'dag', 'ag', ''),
#  (43, 'dsgda', 'dag', 'ag', 'gagd', 'sag', 'dag', 'ag', 'fdgfdgd'),
#  (44, 'dsgda', 'dag', 'ag', 'gagd', 'sag', 'dag', 'ag', 'fdgfdgd'),
#  (45, 'dsgda', 'dag', 'ag', 'gagd', 'sag', 'dag', 'ag', 'fdgfdgd'),
#  (46, 'fdg', 'gsgd', 'fds', 'dfh', 'sh', 'fdsh', 'shfd', 'hfs'),
#  (47, 'fdg', 'gsgd', 'fds', 'dfh', 'sh', 'fdsh', 'shfd', 'hfs'),
#  (48, 'fdg', 'gsgd', 'fds', 'dfh', 'sh', 'fdsh', 'shfd', 'hfs'),
#  (49, 'fg', 'fg', 'dfg', 'dg', 'dg', 'df', 'df', ''),
#  (50, 'fd', 'df', 'fdg', 'df', 'hdf', 'dfh', 'fhd', ''),
#  (51, 'gfg', 'fh', 'dfh', 'dfh', 'df', 'hfd', 'dfh', ''),
#  (52, 'gfg', 'fh', 'dfh', 'dfh', 'df', 'hfd', 'dfh', 'dsfdsf'),
#  (53, 'dfs', 'dsfg', 'dfsg', 'fh', 'df', 'hdf', 'dfh', ''),
#  (54, 'dsfga', 'dag', 'ag', 'fg', 'fg', 'fdg', 'sfg', ''),
#  (55, 'dsfga', 'dag', 'ag', 'fg', 'fg', 'fdg', 'sfg', ''),
#  (56, 'fgs', 'g', 'fdg', 'g', 'gf', 'fg', 'sg', ''),
#  (57, 'ga', 'dsa', 'adgs', 'ag', 'dga', 'dg', 'dga', ''),
#  (58, 'sfdsd', 'sd', 'sd', 'sdg', 'sdg', 'sdg', 'sdg', ''),
#  (59, 'daf', 'asdf', 'asg', 'ga', 'ga', 'ga', 'ag', ''),
#  (60, 'fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  (61, 'fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  (62, 'fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  (63, 'fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  (64, 'fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  (65, 'sdfs', 'dfgfd', 'fdgd', 'dfg', 'dfg', 'fg', 'dfg', ''),
#  (66, 'fgfs', 'dfg', 'gsfd', 'gf', 'dfgs', 'd', 'sfdg', ''),
#  (67, '43', 'sdf', 'sdg', 'g', 'g', 'gds', 'ds', ''),
#  (68, '06/02/2020', 'sd', 'gd', 'sdg', 'sd', 'sd', 'sdf', ''),
#  (69, '06/02/2020', 'sd', 'gd', 'sdg', 'sd', 'sd', 'sdf', ''),
#  (70, '06/02/2020', 'dsf', 'adf', 'adf', 'adf', 'adsf', 'dfg', ''),
#  (71, '06/02/2020', 'dsf', 'adf', 'adf', 'adf', 'adsf', 'dfg', ''),
#  (72, '06/02/2020', 'dsf', 'adf', 'adf', 'adf', 'adsf', 'dfg', ''),
#  (73, '06/02/2020', 'dsf', 'adf', 'adf', 'adf', 'adsf', 'dfg', ''),
#  (74, '06/10/2020', 'hdfh', 'dfd', 'fd', 'fdg', 'gf', 'df', ''),
#  (75, '06/10/2020', 'hdfh', 'dfd', 'fd', 'fdg', 'gf', 'df', ''),
#  (76, '06/10/2020', 'hdfh', 'dfd', 'fd', 'fdg', 'gf', 'df', ''),
#  (77, '06/17/2020', 'rgrd', 'dfg', 'df', 'df', 'dh', 'fd', ''),
#  (78, '06/17/2020', 'rgrd', 'dfg', 'df', 'df', 'dh', 'fd', ''),
#  (79, '06/10/2020', 'xv', 'xg', 'dg', 'g', 'dg', 'gs', ''),
#  (80, '06/01/2020', 'cxzg', 'zfg', 'zfdg', 'dzfg', 'dzfg', 'zdfg', ''),
#  (81, '06/01/2020', 'cxzg', 'zfg', 'zfdg', 'dzfg', 'dzfg', 'zdfg', ''),
#  (82, '06/01/2020', 'cxzg', 'zfg', 'zfdg', 'dzfg', 'dzfg', 'zdfg', ''),
#  (83, '06/02/2020', 56, 'ch', 'fsh', 'sf', 'sfh', 'sfh', ''),
#  (84, '06/10/2020', 34, 'gas', 23, 56, 'Remco', 'Remco', 'comment'),
#  (85, '06/11/2020', 34, 'gas', 23, 56, 'Remco', 'Remco', 'comment'),
#  (86, '06/02/2020', 23, '32', 'fsd', 'dfg', 'fdg', 'dfsg', '')]

# %%
results = session.query(pettyCash.date, pettyCash.receipt_number, pettyCash.description,\
                        pettyCash.amount_deposited, pettyCash.amount_withdrawn, pettyCash.amount_receivedby,\
                        pettyCash.amount_approvedby, pettyCash.comments)\
                        .filter(pettyCash.date > '05/27/2020').all()
results
# Out:
# [('05/30/2020', None, None, None, None, None, None, None),
#  ('sdsd', 'sdf', 'sdf', 'sdf', 'sdf', 'sdf', 'ds', ''),
#  ('sdg', 'sdg', 'sd', 'sdg', 'sg', 'sdg', 'sdg', ''),
#  ('gsg', 3, 'xc', 44, 34, 'fgfdg', 'sgsg', ''),
#  ('gsg', 3, 'xc', 44, 34, 'fgfdg', 'sgsg', ''),
#  ('sdf', 'sf', 'gsdg', 'sgs', 'sdgs', 'sdgsd', 'sdg', ''),
#  ('df', 'df', 'dfg', 'dfg', 'dfg', 'fdg', 'dfg', ''),
#  ('fgfg', 'sg', 'sg', 'bg', 'sg', 'sgd', 'sg', ''),
#  ('cg', 'gs', 'sdgs', 'sdg', 'sg', 'sdg', 'sdg', ''),
#  ('fhh', 'fh', 'fgh', 'fgu', 'fu', 'fu', 'tu', ''),
#  ('fghgf', 'hfh', 'hgh', 'fgh', 'fgh', 'fgh', 'h', ''),
#  ('ghg', 'fhh', 'dgdg', 'dgdf', 'gdgdfg', 'dgdf', 'dg', ''),
#  ('hf', 'hdh', 'dfh', 'dfh', 'dfh', 'h', 'dfh', ''),
#  ('vsfs', 'dsfds', 'sdfsd', 'sdvsd', 'vzv', 'zv', 'zxv', ''),
#  ('ggg', 'dg', 'fdgs', 'sdfg', 'dfg', 'dfg', 'g', ''),
#  ('sdf', 'sdf', 'asdg', 'sg', 'sag', 'sag', 'sag', ''),
#  ('sgs', 'sd', 'sdg', 'sg', 'sdg', 'sdg', 'sg', ''),
#  ('sdfds', 'sgd', 'sdg', 'sdg', 'sdg', 'sdg', 'sdg', ''),
#  ('dfg', 'dfh', 'dfh', 'he', 'gre', 'dg', 'dg', ''),
#  ('sgs', 'ag', 'adg', 'asdg', 'asg', 'gag', 'agd', ''),
#  ('dhd', 'sh', 'dh', 'dfh', 'dfh', 'dfh', 'dfh', ''),
#  ('dfg', 'fdsh', 'dfsh', 'dfh', 'dh', 'dfh', 'dfh', ''),
#  ('sgsg', 'sf', 'sdg', 'sgd', 'sdg', 'sgd', 'sdg', ''),
#  ('dg', 'dfh', 'dh', 'dh', 'dfh', 'dh', 'dfh', ''),
#  ('fgg', 'g', 'adg', 'dsag', 'adg', 'agd', 'agsd', ''),
#  ('fgfd', 'dg', 'sg', 'sg', 'sg', 'sdg', 'sg', ''),
#  ('cvb', 'bdb', 'dg', 'dfg', 'dfg', 'dfg', 'dfg', ''),
#  ('sdfsd', 'sf', 'sf', 'sdf', 'sdf', 'sdf', 'sdf', ''),
#  ('sgsd', 'sdg', 'ag', 'dfg', 'dfag', 'adfg', 'dafg', ''),
#  ('sgsd', 'sdg', 'ag', 'dfg', 'dfag', 'adfg', 'dafg', ''),
#  ('sgsd', 'sdg', 'ag', '', 'dfag', 'adfg', 'dafg', ''),
#  ('sgsd', 'sdg', 'ag', '', 'dfag', 'adfg', 'dafg', ''),
#  ('fsdg', 'sdf', 'fsdh', 'dfg', 'afd', 'hag', 'fgaf', ''),
#  ('fxb', 'sg', 'sg', 'sg', 'sg', 's', 'sdg', ''),
#  ('dfg', 'g', 'g', 'dfg', 'dfg', 'dfg', 'dfg', ''),
#  ('dfg', 'g', 'g', 'dfg', 'dfg', 'dfg', 'dfg', ''),
#  ('fdg', 'sg', 'sg', 'sg', 'sdg', 'sdg', 'sdg', ''),
#  ('ds', 'dsf', 'dsf', 'df', 'xcb', 'cxb', 'xcb', ''),
#  ('gdg', 'sfdg', 'sdfh', 'dh', 'sfd', 'sh', 'hsdf', ''),
#  ('dsgda', 'dag', 'ag', 'gagd', 'sag', 'dag', 'ag', ''),
#  ('dsgda', 'dag', 'ag', 'gagd', 'sag', 'dag', 'ag', 'fdgfdgd'),
#  ('dsgda', 'dag', 'ag', 'gagd', 'sag', 'dag', 'ag', 'fdgfdgd'),
#  ('dsgda', 'dag', 'ag', 'gagd', 'sag', 'dag', 'ag', 'fdgfdgd'),
#  ('fdg', 'gsgd', 'fds', 'dfh', 'sh', 'fdsh', 'shfd', 'hfs'),
#  ('fdg', 'gsgd', 'fds', 'dfh', 'sh', 'fdsh', 'shfd', 'hfs'),
#  ('fdg', 'gsgd', 'fds', 'dfh', 'sh', 'fdsh', 'shfd', 'hfs'),
#  ('fg', 'fg', 'dfg', 'dg', 'dg', 'df', 'df', ''),
#  ('fd', 'df', 'fdg', 'df', 'hdf', 'dfh', 'fhd', ''),
#  ('gfg', 'fh', 'dfh', 'dfh', 'df', 'hfd', 'dfh', ''),
#  ('gfg', 'fh', 'dfh', 'dfh', 'df', 'hfd', 'dfh', 'dsfdsf'),
#  ('dfs', 'dsfg', 'dfsg', 'fh', 'df', 'hdf', 'dfh', ''),
#  ('dsfga', 'dag', 'ag', 'fg', 'fg', 'fdg', 'sfg', ''),
#  ('dsfga', 'dag', 'ag', 'fg', 'fg', 'fdg', 'sfg', ''),
#  ('fgs', 'g', 'fdg', 'g', 'gf', 'fg', 'sg', ''),
#  ('ga', 'dsa', 'adgs', 'ag', 'dga', 'dg', 'dga', ''),
#  ('sfdsd', 'sd', 'sd', 'sdg', 'sdg', 'sdg', 'sdg', ''),
#  ('daf', 'asdf', 'asg', 'ga', 'ga', 'ga', 'ag', ''),
#  ('fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  ('fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  ('fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  ('fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  ('fhdf', 'dfh', 'dfh', 'dfh', 'dfh', 'dh', 'dfh', ''),
#  ('sdfs', 'dfgfd', 'fdgd', 'dfg', 'dfg', 'fg', 'dfg', ''),
#  ('fgfs', 'dfg', 'gsfd', 'gf', 'dfgs', 'd', 'sfdg', ''),
#  ('43', 'sdf', 'sdg', 'g', 'g', 'gds', 'ds', ''),
#  ('06/02/2020', 'sd', 'gd', 'sdg', 'sd', 'sd', 'sdf', ''),
#  ('06/02/2020', 'sd', 'gd', 'sdg', 'sd', 'sd', 'sdf', ''),
#  ('06/02/2020', 'dsf', 'adf', 'adf', 'adf', 'adsf', 'dfg', ''),
#  ('06/02/2020', 'dsf', 'adf', 'adf', 'adf', 'adsf', 'dfg', ''),
#  ('06/02/2020', 'dsf', 'adf', 'adf', 'adf', 'adsf', 'dfg', ''),
#  ('06/02/2020', 'dsf', 'adf', 'adf', 'adf', 'adsf', 'dfg', ''),
#  ('06/10/2020', 'hdfh', 'dfd', 'fd', 'fdg', 'gf', 'df', ''),
#  ('06/10/2020', 'hdfh', 'dfd', 'fd', 'fdg', 'gf', 'df', ''),
#  ('06/10/2020', 'hdfh', 'dfd', 'fd', 'fdg', 'gf', 'df', ''),
#  ('06/17/2020', 'rgrd', 'dfg', 'df', 'df', 'dh', 'fd', ''),
#  ('06/17/2020', 'rgrd', 'dfg', 'df', 'df', 'dh', 'fd', ''),
#  ('06/10/2020', 'xv', 'xg', 'dg', 'g', 'dg', 'gs', ''),
#  ('06/01/2020', 'cxzg', 'zfg', 'zfdg', 'dzfg', 'dzfg', 'zdfg', ''),
#  ('06/01/2020', 'cxzg', 'zfg', 'zfdg', 'dzfg', 'dzfg', 'zdfg', ''),
#  ('06/01/2020', 'cxzg', 'zfg', 'zfdg', 'dzfg', 'dzfg', 'zdfg', ''),
#  ('06/02/2020', 56, 'ch', 'fsh', 'sf', 'sfh', 'sfh', ''),
#  ('06/10/2020', 34, 'gas', 23, 56, 'Remco', 'Remco', 'comment'),
#  ('06/11/2020', 34, 'gas', 23, 56, 'Remco', 'Remco', 'comment'),
#  ('06/02/2020', 23, '32', 'fsd', 'dfg', 'fdg', 'dfsg', '')]

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-0003c4ecf91f> in <module>
# ----> 1 jsonify({'result': results})
#
# ~\Anaconda3\lib\site-packages\flask\json\__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# ~\Anaconda3\lib\site-packages\werkzeug\local.py in __getattr__(self, name)
#     346         if name == "__members__":
#     347             return dir(self._get_current_object())
# --> 348         return getattr(self._get_current_object(), name)
#     349
#     350     def __setitem__(self, key, value):
#
# ~\Anaconda3\lib\site-packages\werkzeug\local.py in _get_current_object(self)
#     305         """
#     306         if not hasattr(self.__local, "__release_local__"):
# --> 307             return self.__local()
#     308         try:
#     309             return getattr(self.__local, self.__name__)
#
# ~\Anaconda3\lib\site-packages\flask\globals.py in _find_app()
#      50     top = _app_ctx_stack.top
#      51     if top is None:
# ---> 52         raise RuntimeError(_app_ctx_err_msg)
#      53     return top.app
#      54
#
# RuntimeError: Working outside of application context.
#
# This typically means that you attempted to use functionality that needed
# to interface with the current application object in some way. To solve
# this, set up an application context with app.app_context().  See the
# documentation for more information.
